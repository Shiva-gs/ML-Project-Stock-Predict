# %%
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

# %%
tables = pd.read_html(url)
tables
# Out:
# [    Symbol                         Security SEC filings  \
#  0      MMM                       3M Company     reports
#  1      ABT              Abbott Laboratories     reports
#  2     ABBV                      AbbVie Inc.     reports
#  3     ABMD                      ABIOMED Inc     reports
#  4      ACN                    Accenture plc     reports
#  5     ATVI              Activision Blizzard     reports
#  6     ADBE                Adobe Systems Inc     reports
#  7      AMD       Advanced Micro Devices Inc     reports
#  8      AAP               Advance Auto Parts     reports
#  9      AES                         AES Corp     reports
#  10     AFL                        AFLAC Inc     reports
#  11       A         Agilent Technologies Inc     reports
#  12     APD     Air Products & Chemicals Inc     reports
#  13    AKAM          Akamai Technologies Inc     reports
#  14     ALK             Alaska Air Group Inc     reports
# ...

# %%
df_500 = tables[0]
df_500
# Out:
#     Symbol                         Security SEC filings  \
# 0      MMM                       3M Company     reports
# 1      ABT              Abbott Laboratories     reports
# 2     ABBV                      AbbVie Inc.     reports
# 3     ABMD                      ABIOMED Inc     reports
# 4      ACN                    Accenture plc     reports
# 5     ATVI              Activision Blizzard     reports
# 6     ADBE                Adobe Systems Inc     reports
# 7      AMD       Advanced Micro Devices Inc     reports
# 8      AAP               Advance Auto Parts     reports
# 9      AES                         AES Corp     reports
# 10     AFL                        AFLAC Inc     reports
# 11       A         Agilent Technologies Inc     reports
# 12     APD     Air Products & Chemicals Inc     reports
# 13    AKAM          Akamai Technologies Inc     reports
# 14     ALK             Alaska Air Group Inc     reports
# 15     ALB                   Albemarle Corp     reports
# ...

# %%
df_500.groupby(['GICS Sector'])['Symbol'].count()
# Out:
# GICS Sector
# Communication Services    26
# Consumer Discretionary    64
# Consumer Staples          33
# Energy                    28
# Financials                66
# Health Care               61
# Industrials               70
# Information Technology    70
# Materials                 28
# Real Estate               31
# Utilities                 28
# Name: Symbol, dtype: int64

# %%
realEstate_list = df_500[df_500['GICS Sector']=='Real Estate']['Symbol'].to_list()
communication_list = df_500[df_500['GICS Sector']=='Communication Services']['Symbol'].to_list()
consumerStaples_list = df_500[df_500['GICS Sector']=='Consumer Staples']['Symbol'].to_list()
consumer_list =  df_500[df_500['GICS Sector']=='Consumer Discretionary']['Symbol'].to_list()
energy_list = df_500[df_500['GICS Sector']=='Energy']['Symbol'].to_list()
financials_list = df_500[df_500['GICS Sector']=='Financials']['Symbol'].to_list()
health_list = df_500[df_500['GICS Sector']=='Health Care']['Symbol'].to_list()
industrials_list = df_500[df_500['GICS Sector']=='Industrials']['Symbol'].to_list()
information_list = df_500[df_500['GICS Sector']=='Information Technology']['Symbol'].to_list()
materials_list = df_500[df_500['GICS Sector']=='Materials']['Symbol'].to_list()
utilities_list = df_500[df_500['GICS Sector']=='Utilities']['Symbol'].to_list()

# %%
print(f'Real Estate --------------------------------------------------{realEstate_list}')
print(f'communication Services --------------------------------------------------{communication_list}')
print(f'comsumer Discretionary--------------------------------------------------{consumer_list}')
print(f'comsumer Staples --------------------------------------------------{consumerStaples_list}')
print(f'Energy --------------------------------------------------{energy_list}')
print(f'financial--------------------------------------------------{financials_list}')
print(f'health --------------------------------------------------{health_list}')
print(f'industrials --------------------------------------------------{industrials_list}')
print(f'information --------------------------------------------------{information_list}')
print(f'materials --------------------------------------------------{materials_list}')
print(f'utilities --------------------------------------------------{utilities_list}')
# Out:
# Real Estate --------------------------------------------------['ARE', 'AMT', 'AIV', 'AVB', 'BXP', 'CBRE', 'CCI', 'DLR', 'DRE', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'PEAK', 'HST', 'IRM', 'KIM', 'MAA', 'PLD', 'PSA', 'O', 'REG', 'SBAC', 'SPG', 'SLG', 'UDR', 'VTR', 'VNO', 'WELL', 'WY']
# communication Services --------------------------------------------------['ATVI', 'GOOGL', 'GOOG', 'T', 'CTL', 'CHTR', 'CMCSA', 'DISCA', 'DISCK', 'DISH', 'EA', 'FB', 'FOXA', 'FOX', 'IPG', 'LYV', 'NFLX', 'NWSA', 'NWS', 'OMC', 'TMUS', 'TTWO', 'TWTR', 'VZ', 'VIAC', 'DIS']
# ...
